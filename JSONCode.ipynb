# %%
    import sqlalchemy
    from sqlalchemy.ext.automap import automap_base
    from sqlalchemy.orm import Session
    from sqlalchemy import create_engine
    from sqlalchemy import func
    from flask import Flask, jsonify

# %%
# Create an engine for the database
engine = create_engine("postgresql://test:12345@localhost/app_rankings")

# %%
# Reflect Database into ORM classes
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['category', 'application', 'publisher', 'ranking', 'platform']

# %% [markdown]
# Save references to the tables

# %%
category = Base.classes.category
application = Base.classes.application
publisher = Base.classes.publisher
ranking = Base.classes.ranking
platform = Base.classes.platform

# %%
# Create a database session object
session = Session(engine)

# %%
sel = [platform.platform, publisher.publisher_name, application.app_name, ranking.date, category.category, ranking.rank]

# %%
giant_query = session.query(*sel).filter(ranking.app_id == application.app_id).filter(ranking.category_id == category.category_id).filter(ranking.platform_id == platform.platform_id).filter(application.publisher_id == publisher.publisher_id).order_by(platform.platform).order_by(publisher.publisher_name).order_by(application.app_name).order_by(ranking.date).order_by(category.category).order_by(ranking.rank).limit(50).all()
# Out:
# ---------------------------------------------------------------------------
# InsufficientPrivilege                     Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1276                 if not evt_handled:
# -> 1277                     self.dialect.do_execute(
#    1278                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# InsufficientPrivilege: permission denied for table platform
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-38-e36647dd5f26> in <module>
# ----> 1 giant_query = session.query(*sel).filter(ranking.app_id == application.app_id).filter(ranking.category_id == category.category_id).filter(ranking.platform_id == platform.platform_id).filter(application.publisher_id == publisher.publisher_id).order_by(platform.platform).order_by(publisher.publisher_name).order_by(application.app_name).order_by(ranking.date).order_by(category.category).order_by(ranking.rank).limit(50).all()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/orm/query.py in all(self)
#    3339                 :ref:`faq_query_deduplicating`
#    3340         """
# -> 3341         return list(self)
#    3342
#    3343     @_generative(_no_clauseelement_condition)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/orm/query.py in __iter__(self)
#    3501         if self._autoflush and not self._populate_existing:
#    3502             self.session._autoflush()
# -> 3503         return self._execute_and_instances(context)
#    3504
#    3505     def __str__(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/orm/query.py in _execute_and_instances(self, querycontext)
#    3526         )
#    3527
# -> 3528         result = conn.execute(querycontext.statement, self._params)
#    3529         return loading.instances(querycontext.query, result, querycontext)
#    3530
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#    1012             )
#    1013         else:
# -> 1014             return meth(self, multiparams, params)
#    1015
#    1016     def _execute_function(self, func, multiparams, params):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1125             )
#    1126
# -> 1127         ret = self._execute_context(
#    1128             dialect,
#    1129             dialect.execution_ctx_cls._init_compiled,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315
#    1316         except BaseException as e:
# -> 1317             self._handle_dbapi_exception(
#    1318                 e, statement, parameters, cursor, context
#    1319             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1510             elif should_wrap:
# -> 1511                 util.raise_(
#    1512                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1513                 )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275                             break
#    1276                 if not evt_handled:
# -> 1277                     self.dialect.do_execute(
#    1278                         cursor, statement, parameters, context
#    1279                     )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     591
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#     595     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.InsufficientPrivilege) permission denied for table platform
#
# [SQL: SELECT platform.platform AS platform_platform, publisher.publisher_name AS publisher_publisher_name, application.app_name AS application_app_name, ranking.date AS ranking_date, category.category AS category_category, ranking.rank AS ranking_rank
# FROM platform, publisher, application, ranking, category
# WHERE ranking.app_id = application.app_id AND ranking.category_id = category.category_id AND ranking.platform_id = platform.platform_id AND application.publisher_id = publisher.publisher_id ORDER BY platform.platform, publisher.publisher_name, application.app_name, ranking.date, category.category, ranking.rank
#  LIMIT %(param_1)s]
# [parameters: {'param_1': 50}]
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %%
giant_query
# Out:
# [('Android', '1Debit', 'Chime - Mobile Banking', '2021-01-26', 'Free', '140'),
#  ('Android', '1Debit', 'Chime - Mobile Banking', '2021-01-27', 'Free', '133'),
#  ('Android',
#   '2K Games',
#   'Civilization Revolution 2',
#   '2021-01-26',
#   'Paid',
#   '194'),
#  ('Android',
#   '2K Games',
#   'Civilization Revolution 2',
#   '2021-01-27',
#   'Paid',
#   '198'),
#  ('Android', '2K Games', 'NBA 2K20', '2021-01-26', 'Paid', '54'),
#  ('Android', '2K Games', 'NBA 2K20', '2021-01-27', 'Paid', '65'),
#  ('Android',
#   '2K Games',
#   'WWE SuperCard - Multiplayer Collector Card Game',
#   '2021-01-26',
#   'Grossing',
#   '144'),
#  ('Android',
#   '2K Games',
#   'WWE SuperCard - Multiplayer Collector Card Game',
#   '2021-01-27',
#   'Grossing',
#   '141'),
#  ('Android', '2K Games', 'XCOM®: Enemy Within', '2021-01-26', 'Paid', '227'),
#  ('Android', '2K Games', 'XCOM®: Enemy Within', '2021-01-27', 'Paid', '248'),
#  ('Android',
#   '2kit Consulting',
#   'Screen Mirroring Pro App',
#   '2021-01-26',
#   'Paid',
#   '93'),
#  ('Android',
#   '2kit Consulting',
#   'Screen Mirroring Pro App',
#   '2021-01-27',
#   'Paid',
#   '88'),
#  ('Android',
#   '2kit Consulting',
#   'Screen Mirroring Pro for Fire TV',
#   '2021-01-26',
#   'Paid',
#   '112'),
#  ('Android',
#   '2kit Consulting',
#   'Screen Mirroring Pro for Fire TV',
#   '2021-01-27',
#   'Paid',
#   '112'),
#  ('Android',
#   '2kit Consulting',
#   'Screen Mirroring Pro for Roku',
#   '2021-01-26',
#   'Paid',
#   '80'),
#  ('Android',
#   '2kit Consulting',
#   'Screen Mirroring Pro for Roku',
#   '2021-01-27',
#   'Paid',
#   '77'),
#  ('Android',
#   '2kit Consulting',
#   'Video & TV Cast + Fire TV | Web Video Browser',
#   '2021-01-26',
#   'Paid',
#   '132'),
#  ('Android',
#   '2kit Consulting',
#   'Video & TV Cast + Fire TV | Web Video Browser',
#   '2021-01-27',
#   'Paid',
#   '139'),
#  ('Android',
#   '2kit Consulting',
#   'Video & TV Cast + Google Cast: Android TV Streamer',
#   '2021-01-26',
#   'Paid',
#   '192'),
#  ('Android',
#   '2kit Consulting',
#   'Video & TV Cast + Google Cast: Android TV Streamer',
#   '2021-01-27',
#   'Paid',
#   '192'),
#  ('Android',
#   '2kit Consulting',
#   'Video & TV Cast + Roku Remote & Movie Stream App',
#   '2021-01-26',
#   'Paid',
#   '143'),
#  ('Android',
#   '2kit Consulting',
#   'Video & TV Cast + Roku Remote & Movie Stream App',
#   '2021-01-27',
#   'Paid',
#   '147'),
#  ('Android',
#   '2kit Consulting',
#   'Video & TV Cast | Ultimate Edition',
#   '2021-01-26',
#   'Paid',
#   '109'),
#  ('Android',
#   '2kit Consulting',
#   'Video & TV Cast | Ultimate Edition',
#   '2021-01-27',
#   'Paid',
#   '113'),
#  ('Android', '37games', 'Puzzles & Conquest', '2021-01-26', 'Grossing', '192'),
#  ('Android', '37games', 'Puzzles & Conquest', '2021-01-27', 'Grossing', '193'),
#  ('Android', '37games', 'Puzzles & Survival', '2021-01-26', 'Free', '162'),
#  ('Android', '37games', 'Puzzles & Survival', '2021-01-26', 'Grossing', '67'),
#  ('Android', '37games', 'Puzzles & Survival', '2021-01-27', 'Free', '161'),
#  ('Android', '37games', 'Puzzles & Survival', '2021-01-27', 'Grossing', '67'),
#  ('Android', '44SEVEN MEDIA', '75 Hard', '2021-01-26', 'Paid', '64'),
#  ('Android', '44SEVEN MEDIA', '75 Hard', '2021-01-27', 'Paid', '59'),
#  ('Android', '505 Games', 'Human: Fall Flat', '2021-01-26', 'Paid', '24'),
#  ('Android', '505 Games', 'Human: Fall Flat', '2021-01-27', 'Paid', '20'),
#  ('Android', '505 Games', 'Terraria', '2021-01-26', 'Paid', '8'),
#  ('Android', '505 Games', 'Terraria', '2021-01-27', 'Paid', '8'),
#  ('Android',
#   '89Trillion',
#   'Art of War: Legions',
#   '2021-01-26',
#   'Grossing',
#   '165'),
#  ('Android',
#   '89Trillion',
#   'Art of War: Legions',
#   '2021-01-27',
#   'Grossing',
#   '168'),
#  ('Android',
#   'ACME AtronOmatic',
#   'MyRadar Weather Radar Ad Free',
#   '2021-01-26',
#   'Paid',
#   '215'),
#  ('Android',
#   'ACME AtronOmatic',
#   'MyRadar Weather Radar Ad Free',
#   '2021-01-27',
#   'Paid',
#   '211'),
#  ('Android', 'ADP, INC.', 'ADP Mobile Solutions', '2021-01-26', 'Free', '283'),
#  ('Android', 'ADP, INC.', 'ADP Mobile Solutions', '2021-01-27', 'Free', '277'),
#  ('Android', 'ADVA Soft', 'TouchRetouch', '2021-01-26', 'Paid', '84'),
#  ('Android', 'ADVA Soft', 'TouchRetouch', '2021-01-27', 'Paid', '79'),
#  ('Android', 'AFELL APPS', 'Nano Teleprompter', '2021-01-26', 'Paid', '214'),
#  ('Android', 'AFELL APPS', 'Nano Teleprompter', '2021-01-27', 'Paid', '208'),
#  ('Android',
#   'AGaming',
#   'The Sun Origin: Post-apocalyptic action shooter',
#   '2021-01-26',
#   'Paid',
#   '255'),
#  ('Android',
#   'AGaming',
#   'The Sun Origin: Post-apocalyptic action shooter',
#   '2021-01-27',
#   'Paid',
#   '266'),
#  ('Android', 'AI Factory', 'Chess', '2021-01-26', 'Paid', '57'),
#  ('Android', 'AI Factory', 'Chess', '2021-01-27', 'Paid', '57')]

# %%
all_apps = []

# %%
for platform, publisher_name, app_name, date, category, rank  in giant_query:
    app_rankings_dict = {}
    publisher_name_dict = {}
    app_name_dict = {}
    date_dict = {}
    category_dict = {}

    app_rankings_dict["platform"] = platform
    app_rankings_dict["publisher"] = publisher_name_dict 
    publisher_name_dict["publisher_name"] = publisher_name
    publisher_name_dict["app"] = app_name_dict
    publisher_name_dict["app_name"] = app_name
    publisher_name_dict["date"] = date_dict
    date_dict["date"] = date
    date_dict["category"] = category_dict
    category_dict["category"] = category
    category_dict["rank"] = rank
    all_apps.append(app_rankings_dict)

# %%
all_apps
# Out:
# [{'platform': 'Android',
#   'publisher': {'publisher_name': '1Debit',
#    'app': {},
#    'app_name': 'Chime - Mobile Banking',
#    'date': {'date': '2021-01-26',
#     'category': {'category': 'Free', 'rank': '140'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '1Debit',
#    'app': {},
#    'app_name': 'Chime - Mobile Banking',
#    'date': {'date': '2021-01-27',
#     'category': {'category': 'Free', 'rank': '133'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {},
#    'app_name': 'Civilization Revolution 2',
#    'date': {'date': '2021-01-26',
#     'category': {'category': 'Paid', 'rank': '194'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {},
#    'app_name': 'Civilization Revolution 2',
#    'date': {'date': '2021-01-27',
#     'category': {'category': 'Paid', 'rank': '198'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {},
#    'app_name': 'NBA 2K20',
#    'date': {'date': '2021-01-26',
#     'category': {'category': 'Paid', 'rank': '54'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {},
#    'app_name': 'NBA 2K20',
#    'date': {'date': '2021-01-27',
#     'category': {'category': 'Paid', 'rank': '65'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {},
#    'app_name': 'WWE SuperCard - Multiplayer Collector Card Game',
#    'date': {'date': '2021-01-26',
#     'category': {'category': 'Grossing', 'rank': '144'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {},
#    'app_name': 'WWE SuperCard - Multiplayer Collector Card Game',
#    'date': {'date': '2021-01-27',
#     'category': {'category': 'Grossing', 'rank': '141'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {},
#    'app_name': 'XCOM®: Enemy Within',
#    'date': {'date': '2021-01-26',
#     'category': {'category': 'Paid', 'rank': '227'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {},
#    'app_name': 'XCOM®: Enemy Within',
#    'date': {'date': '2021-01-27',
#     'category': {'category': 'Paid', 'rank': '248'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {},
#    'app_name': 'Screen Mirroring Pro App',
#    'date': {'date': '2021-01-26',
#     'category': {'category': 'Paid', 'rank': '93'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {},
#    'app_name': 'Screen Mirroring Pro App',
#    'date': {'date': '2021-01-27',
#     'category': {'category': 'Paid', 'rank': '88'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {},
#    'app_name': 'Screen Mirroring Pro for Fire TV',
#    'date': {'date': '2021-01-26',
#     'category': {'category': 'Paid', 'rank': '112'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {},
#    'app_name': 'Screen Mirroring Pro for Fire TV',
#    'date': {'date': '2021-01-27',
#     'category': {'category': 'Paid', 'rank': '112'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {},
#    'app_name': 'Screen Mirroring Pro for Roku',
#    'date': {'date': '2021-01-26',
#     'category': {'category': 'Paid', 'rank': '80'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {},
#    'app_name': 'Screen Mirroring Pro for Roku',
#    'date': {'date': '2021-01-27',
#     'category': {'category': 'Paid', 'rank': '77'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {},
#    'app_name': 'Video & TV Cast + Fire TV | Web Video Browser',
#    'date': {'date': '2021-01-26',
#     'category': {'category': 'Paid', 'rank': '132'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {},
#    'app_name': 'Video & TV Cast + Fire TV | Web Video Browser',
#    'date': {'date': '2021-01-27',
#     'category': {'category': 'Paid', 'rank': '139'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {},
#    'app_name': 'Video & TV Cast + Google Cast: Android TV Streamer',
#    'date': {'date': '2021-01-26',
#     'category': {'category': 'Paid', 'rank': '192'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {},
#    'app_name': 'Video & TV Cast + Google Cast: Android TV Streamer',
#    'date': {'date': '2021-01-27',
#     'category': {'category': 'Paid', 'rank': '192'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {},
#    'app_name': 'Video & TV Cast + Roku Remote & Movie Stream App',
#    'date': {'date': '2021-01-26',
#     'category': {'category': 'Paid', 'rank': '143'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {},
#    'app_name': 'Video & TV Cast + Roku Remote & Movie Stream App',
#    'date': {'date': '2021-01-27',
#     'category': {'category': 'Paid', 'rank': '147'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {},
#    'app_name': 'Video & TV Cast | Ultimate Edition',
#    'date': {'date': '2021-01-26',
#     'category': {'category': 'Paid', 'rank': '109'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {},
#    'app_name': 'Video & TV Cast | Ultimate Edition',
#    'date': {'date': '2021-01-27',
#     'category': {'category': 'Paid', 'rank': '113'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '37games',
#    'app': {},
#    'app_name': 'Puzzles & Conquest',
#    'date': {'date': '2021-01-26',
#     'category': {'category': 'Grossing', 'rank': '192'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '37games',
#    'app': {},
#    'app_name': 'Puzzles & Conquest',
#    'date': {'date': '2021-01-27',
#     'category': {'category': 'Grossing', 'rank': '193'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '37games',
#    'app': {},
#    'app_name': 'Puzzles & Survival',
#    'date': {'date': '2021-01-26',
#     'category': {'category': 'Free', 'rank': '162'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '37games',
#    'app': {},
#    'app_name': 'Puzzles & Survival',
#    'date': {'date': '2021-01-26',
#     'category': {'category': 'Grossing', 'rank': '67'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '37games',
#    'app': {},
#    'app_name': 'Puzzles & Survival',
#    'date': {'date': '2021-01-27',
#     'category': {'category': 'Free', 'rank': '161'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '37games',
#    'app': {},
#    'app_name': 'Puzzles & Survival',
#    'date': {'date': '2021-01-27',
#     'category': {'category': 'Grossing', 'rank': '67'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '44SEVEN MEDIA',
#    'app': {},
#    'app_name': '75 Hard',
#    'date': {'date': '2021-01-26',
#     'category': {'category': 'Paid', 'rank': '64'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '44SEVEN MEDIA',
#    'app': {},
#    'app_name': '75 Hard',
#    'date': {'date': '2021-01-27',
#     'category': {'category': 'Paid', 'rank': '59'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '505 Games',
#    'app': {},
#    'app_name': 'Human: Fall Flat',
#    'date': {'date': '2021-01-26',
#     'category': {'category': 'Paid', 'rank': '24'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '505 Games',
#    'app': {},
#    'app_name': 'Human: Fall Flat',
#    'date': {'date': '2021-01-27',
#     'category': {'category': 'Paid', 'rank': '20'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '505 Games',
#    'app': {},
#    'app_name': 'Terraria',
#    'date': {'date': '2021-01-26',
#     'category': {'category': 'Paid', 'rank': '8'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '505 Games',
#    'app': {},
#    'app_name': 'Terraria',
#    'date': {'date': '2021-01-27',
#     'category': {'category': 'Paid', 'rank': '8'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '89Trillion',
#    'app': {},
#    'app_name': 'Art of War: Legions',
#    'date': {'date': '2021-01-26',
#     'category': {'category': 'Grossing', 'rank': '165'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '89Trillion',
#    'app': {},
#    'app_name': 'Art of War: Legions',
#    'date': {'date': '2021-01-27',
#     'category': {'category': 'Grossing', 'rank': '168'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'ACME AtronOmatic',
#    'app': {},
#    'app_name': 'MyRadar Weather Radar Ad Free',
#    'date': {'date': '2021-01-26',
#     'category': {'category': 'Paid', 'rank': '215'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'ACME AtronOmatic',
#    'app': {},
#    'app_name': 'MyRadar Weather Radar Ad Free',
#    'date': {'date': '2021-01-27',
#     'category': {'category': 'Paid', 'rank': '211'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'ADP, INC.',
#    'app': {},
#    'app_name': 'ADP Mobile Solutions',
#    'date': {'date': '2021-01-26',
#     'category': {'category': 'Free', 'rank': '283'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'ADP, INC.',
#    'app': {},
#    'app_name': 'ADP Mobile Solutions',
#    'date': {'date': '2021-01-27',
#     'category': {'category': 'Free', 'rank': '277'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'ADVA Soft',
#    'app': {},
#    'app_name': 'TouchRetouch',
#    'date': {'date': '2021-01-26',
#     'category': {'category': 'Paid', 'rank': '84'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'ADVA Soft',
#    'app': {},
#    'app_name': 'TouchRetouch',
#    'date': {'date': '2021-01-27',
#     'category': {'category': 'Paid', 'rank': '79'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'AFELL APPS',
#    'app': {},
#    'app_name': 'Nano Teleprompter',
#    'date': {'date': '2021-01-26',
#     'category': {'category': 'Paid', 'rank': '214'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'AFELL APPS',
#    'app': {},
#    'app_name': 'Nano Teleprompter',
#    'date': {'date': '2021-01-27',
#     'category': {'category': 'Paid', 'rank': '208'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'AGaming',
#    'app': {},
#    'app_name': 'The Sun Origin: Post-apocalyptic action shooter',
#    'date': {'date': '2021-01-26',
#     'category': {'category': 'Paid', 'rank': '255'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'AGaming',
#    'app': {},
#    'app_name': 'The Sun Origin: Post-apocalyptic action shooter',
#    'date': {'date': '2021-01-27',
#     'category': {'category': 'Paid', 'rank': '266'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'AI Factory',
#    'app': {},
#    'app_name': 'Chess',
#    'date': {'date': '2021-01-26',
#     'category': {'category': 'Paid', 'rank': '57'}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'AI Factory',
#    'app': {},
#    'app_name': 'Chess',
#    'date': {'date': '2021-01-27',
#     'category': {'category': 'Paid', 'rank': '57'}}}}]
