# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import func
from flask import Flask, jsonify

# %%
# Create an engine for the database
engine = create_engine("postgresql://postgres:soemace123@localhost:5432/app_rankings")

# %%
# Reflect Database into ORM classes
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['application', 'category', 'publisher', 'ranking', 'platform']

# %% [markdown]
# Save references to the tables

# %%
category = Base.classes.category
application = Base.classes.application
publisher = Base.classes.publisher
ranking = Base.classes.ranking
platform = Base.classes.platform

# %%
# Create a database session object
session = Session(engine)

# %%
sel = [platform.platform, publisher.publisher_name, application.app_name, ranking.date, category.category, ranking.rank]

# %%
giant_query = session.query(*sel).filter(ranking.app_id == application.app_id).filter(ranking.category_id == category.category_id).filter(ranking.platform_id == platform.platform_id).filter(application.publisher_id == publisher.publisher_id).order_by(platform.platform).order_by(publisher.publisher_name).order_by(application.app_name).order_by(ranking.date).order_by(category.category).order_by(ranking.rank).limit(50).all()

# %%
giant_query
# Out:
# [('Android',
#   '⭐ Live Wallpapers HD ⭐',
#   'Glitter Live Wallpaper',
#   '2021-01-26',
#   'Free',
#   '192'),
#  ('Android', '1Debit', 'Chime - Mobile Banking', '2021-01-26', 'Free', '140'),
#  ('Android', '1Debit', 'Chime - Mobile Banking', '2021-01-27', 'Free', '133'),
#  ('Android',
#   '2K Games',
#   'Civilization Revolution 2',
#   '2021-01-26',
#   'Paid',
#   '194'),
#  ('Android',
#   '2K Games',
#   'Civilization Revolution 2',
#   '2021-01-27',
#   'Paid',
#   '198'),
#  ('Android', '2K Games', 'NBA 2K20', '2021-01-26', 'Paid', '54'),
#  ('Android', '2K Games', 'NBA 2K20', '2021-01-27', 'Paid', '65'),
#  ('Android',
#   '2K Games',
#   'WWE SuperCard - Multiplayer Collector Card Game',
#   '2021-01-26',
#   'Grossing',
#   '144'),
#  ('Android',
#   '2K Games',
#   'WWE SuperCard - Multiplayer Collector Card Game',
#   '2021-01-27',
#   'Grossing',
#   '141'),
#  ('Android', '2K Games', 'XCOM®: Enemy Within', '2021-01-26', 'Paid', '227'),
#  ('Android', '2K Games', 'XCOM®: Enemy Within', '2021-01-27', 'Paid', '248'),
#  ('Android',
#   '2kit Consulting',
#   'Screen Mirroring Pro App',
#   '2021-01-26',
#   'Paid',
#   '93'),
#  ('Android',
#   '2kit Consulting',
#   'Screen Mirroring Pro App',
#   '2021-01-27',
#   'Paid',
#   '88'),
#  ('Android',
#   '2kit Consulting',
#   'Screen Mirroring Pro for Fire TV',
#   '2021-01-26',
#   'Paid',
#   '112'),
#  ('Android',
#   '2kit Consulting',
#   'Screen Mirroring Pro for Fire TV',
#   '2021-01-27',
#   'Paid',
#   '112'),
#  ('Android',
#   '2kit Consulting',
#   'Screen Mirroring Pro for Roku',
#   '2021-01-26',
#   'Paid',
#   '80'),
#  ('Android',
#   '2kit Consulting',
#   'Screen Mirroring Pro for Roku',
#   '2021-01-27',
#   'Paid',
#   '77'),
#  ('Android',
#   '2kit Consulting',
#   'Video & TV Cast | Ultimate Edition',
#   '2021-01-26',
#   'Paid',
#   '109'),
#  ('Android',
#   '2kit Consulting',
#   'Video & TV Cast | Ultimate Edition',
#   '2021-01-27',
#   'Paid',
#   '113'),
#  ('Android',
#   '2kit Consulting',
#   'Video & TV Cast + Fire TV | Web Video Browser',
#   '2021-01-26',
#   'Paid',
#   '132'),
#  ('Android',
#   '2kit Consulting',
#   'Video & TV Cast + Fire TV | Web Video Browser',
#   '2021-01-27',
#   'Paid',
#   '139'),
#  ('Android',
#   '2kit Consulting',
#   'Video & TV Cast + Google Cast: Android TV Streamer',
#   '2021-01-26',
#   'Paid',
#   '192'),
#  ('Android',
#   '2kit Consulting',
#   'Video & TV Cast + Google Cast: Android TV Streamer',
#   '2021-01-27',
#   'Paid',
#   '192'),
#  ('Android',
#   '2kit Consulting',
#   'Video & TV Cast + Roku Remote & Movie Stream App',
#   '2021-01-26',
#   'Paid',
#   '143'),
#  ('Android',
#   '2kit Consulting',
#   'Video & TV Cast + Roku Remote & Movie Stream App',
#   '2021-01-27',
#   'Paid',
#   '147'),
#  ('Android', '37games', 'Puzzles & Conquest', '2021-01-26', 'Grossing', '192'),
#  ('Android', '37games', 'Puzzles & Conquest', '2021-01-27', 'Grossing', '193'),
#  ('Android', '37games', 'Puzzles & Survival', '2021-01-26', 'Free', '162'),
#  ('Android', '37games', 'Puzzles & Survival', '2021-01-26', 'Grossing', '67'),
#  ('Android', '37games', 'Puzzles & Survival', '2021-01-27', 'Free', '161'),
#  ('Android', '37games', 'Puzzles & Survival', '2021-01-27', 'Grossing', '67'),
#  ('Android', '44SEVEN MEDIA', '75 Hard', '2021-01-26', 'Paid', '64'),
#  ('Android', '44SEVEN MEDIA', '75 Hard', '2021-01-27', 'Paid', '59'),
#  ('Android', '505 Games', 'Human: Fall Flat', '2021-01-26', 'Paid', '24'),
#  ('Android', '505 Games', 'Human: Fall Flat', '2021-01-27', 'Paid', '20'),
#  ('Android', '505 Games', 'Terraria', '2021-01-26', 'Paid', '8'),
#  ('Android', '505 Games', 'Terraria', '2021-01-27', 'Paid', '8'),
#  ('Android',
#   '89Trillion',
#   'Art of War: Legions',
#   '2021-01-26',
#   'Grossing',
#   '165'),
#  ('Android',
#   '89Trillion',
#   'Art of War: Legions',
#   '2021-01-27',
#   'Grossing',
#   '168'),
#  ('Android',
#   'ACME AtronOmatic',
#   'MyRadar Weather Radar Ad Free',
#   '2021-01-26',
#   'Paid',
#   '215'),
#  ('Android',
#   'ACME AtronOmatic',
#   'MyRadar Weather Radar Ad Free',
#   '2021-01-27',
#   'Paid',
#   '211'),
#  ('Android', 'ActiveNetwork', 'Couch to 5K®', '2021-01-26', 'Paid', '231'),
#  ('Android', 'ActiveNetwork', 'Couch to 5K®', '2021-01-27', 'Paid', '269'),
#  ('Android',
#   'Activision Publishing',
#   'Call of Duty:Black Ops Zombies',
#   '2021-01-26',
#   'Paid',
#   '39'),
#  ('Android',
#   'Activision Publishing',
#   'Call of Duty:Black Ops Zombies',
#   '2021-01-27',
#   'Paid',
#   '39'),
#  ('Android',
#   'Activision Publishing',
#   'Call of Duty®: Mobile',
#   '2021-01-26',
#   'Free',
#   '165'),
#  ('Android',
#   'Activision Publishing',
#   'Call of Duty®: Mobile',
#   '2021-01-26',
#   'Grossing',
#   '37'),
#  ('Android',
#   'Activision Publishing',
#   'Call of Duty®: Mobile',
#   '2021-01-27',
#   'Free',
#   '205'),
#  ('Android',
#   'Activision Publishing',
#   'Call of Duty®: Mobile',
#   '2021-01-27',
#   'Grossing',
#   '23'),
#  ('Android',
#   'Adobe',
#   'Adobe Acrobat Reader: PDF Viewer, Editor & Creator',
#   '2021-01-26',
#   'Free',
#   '92')]

# %%
all_apps = []

# %%
platform_previous = 0
publisher_name_previous = 0
app_name_previous = 0
date_previous = 0
category_previous = 0
rank_previous = 0

# %%
# for platform, publisher_name, app_name, date, category, rank  in giant_query:
#     if platform_previous = platform:

#         if publisher_name_previous = publisher:
            
#             if app_name_previous = app_name:
                
#                 if date_previous = date:
#                     category_dict["category"] = category
#                     category_dict["rank"] = rank
#                 else:
#                     date_dict["date"] = date
#                     date_dict["category"] = category_dict
                    
#                     category_dict["category"] = category
#                     category_dict["rank"] = rank
#             else:
#                 app_name_dict["app_name"] = app_name
#                 app_name_dict["date"] = date_dict
                
#                 date_dict["date"] = date
#                 date_dict["category"] = category_dict
    
#                 category_dict["category"] = category
#                 category_dict["rank"] = rank
#     else:
#         all_apps.append(app_rankings_dict)
    
#         app_rankings_dict = {}
#         publisher_name_dict = {}
#         app_name_dict = {}
#         date_dict = {}
#         category_dict = {}
    
#         platform_previous = 0
#         publisher_name_previous = 0
#         app_name_previous = 0
#         date_previous = 0
#         category_previous = 0
#         rank_previous = 0

#         app_rankings_dict["platform"] = platform
#         app_rankings_dict["publisher"] = publisher_name_dict 
    
#         publisher_name_dict["publisher_name"] = publisher_name
#         publisher_name_dict["app"] = app_name_dict
    
#         app_name_dict["app_name"] = app_name
#         app_name_dict["date"] = date_dict
    
#         date_dict["date"] = date
#         date_dict["category"] = category_dict
    
#         category_dict["category"] = category
#         category_dict["rank"] = rank
    
    
#         all_apps.append(app_rankings_dict)

# %%
for platform, publisher_name, app_name, date, category, rank  in giant_query:
    app_rankings_dict = {}
    publisher_name_dict = {}
    app_name_dict = {}
    date_dict = {}
    category_dict = {}

    app_rankings_dict["platform"] = platform
    app_rankings_dict["publisher"] = publisher_name_dict 
    
    publisher_name_dict["publisher_name"] = publisher_name
    publisher_name_dict["app"] = app_name_dict
    
    app_name_dict["app_name"] = app_name
    app_name_dict["date"] = date_dict
    
    date_dict["date"] = date
    date_dict["category"] = category_dict
    
    category_dict["category"] = category
    category_dict["rank"] = rank
    
    
    all_apps.append(app_rankings_dict)

# %%
all_apps
# Out:
# [{'platform': 'Android',
#   'publisher': {'publisher_name': '⭐ Live Wallpapers HD ⭐',
#    'app': {'app_name': 'Glitter Live Wallpaper',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Free', 'rank': '192'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '1Debit',
#    'app': {'app_name': 'Chime - Mobile Banking',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Free', 'rank': '140'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '1Debit',
#    'app': {'app_name': 'Chime - Mobile Banking',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Free', 'rank': '133'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {'app_name': 'Civilization Revolution 2',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '194'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {'app_name': 'Civilization Revolution 2',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '198'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {'app_name': 'NBA 2K20',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '54'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {'app_name': 'NBA 2K20',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '65'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {'app_name': 'WWE SuperCard - Multiplayer Collector Card Game',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Grossing', 'rank': '144'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {'app_name': 'WWE SuperCard - Multiplayer Collector Card Game',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Grossing', 'rank': '141'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {'app_name': 'XCOM®: Enemy Within',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '227'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {'app_name': 'XCOM®: Enemy Within',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '248'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Screen Mirroring Pro App',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '93'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Screen Mirroring Pro App',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '88'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Screen Mirroring Pro for Fire TV',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '112'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Screen Mirroring Pro for Fire TV',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '112'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Screen Mirroring Pro for Roku',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '80'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Screen Mirroring Pro for Roku',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '77'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Video & TV Cast | Ultimate Edition',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '109'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Video & TV Cast | Ultimate Edition',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '113'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Video & TV Cast + Fire TV | Web Video Browser',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '132'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Video & TV Cast + Fire TV | Web Video Browser',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '139'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Video & TV Cast + Google Cast: Android TV Streamer',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '192'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Video & TV Cast + Google Cast: Android TV Streamer',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '192'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Video & TV Cast + Roku Remote & Movie Stream App',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '143'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Video & TV Cast + Roku Remote & Movie Stream App',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '147'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '37games',
#    'app': {'app_name': 'Puzzles & Conquest',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Grossing', 'rank': '192'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '37games',
#    'app': {'app_name': 'Puzzles & Conquest',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Grossing', 'rank': '193'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '37games',
#    'app': {'app_name': 'Puzzles & Survival',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Free', 'rank': '162'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '37games',
#    'app': {'app_name': 'Puzzles & Survival',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Grossing', 'rank': '67'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '37games',
#    'app': {'app_name': 'Puzzles & Survival',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Free', 'rank': '161'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '37games',
#    'app': {'app_name': 'Puzzles & Survival',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Grossing', 'rank': '67'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '44SEVEN MEDIA',
#    'app': {'app_name': '75 Hard',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '64'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '44SEVEN MEDIA',
#    'app': {'app_name': '75 Hard',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '59'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '505 Games',
#    'app': {'app_name': 'Human: Fall Flat',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '24'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '505 Games',
#    'app': {'app_name': 'Human: Fall Flat',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '20'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '505 Games',
#    'app': {'app_name': 'Terraria',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '8'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '505 Games',
#    'app': {'app_name': 'Terraria',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '8'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '89Trillion',
#    'app': {'app_name': 'Art of War: Legions',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Grossing', 'rank': '165'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '89Trillion',
#    'app': {'app_name': 'Art of War: Legions',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Grossing', 'rank': '168'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'ACME AtronOmatic',
#    'app': {'app_name': 'MyRadar Weather Radar Ad Free',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '215'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'ACME AtronOmatic',
#    'app': {'app_name': 'MyRadar Weather Radar Ad Free',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '211'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'ActiveNetwork',
#    'app': {'app_name': 'Couch to 5K®',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '231'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'ActiveNetwork',
#    'app': {'app_name': 'Couch to 5K®',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '269'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'Activision Publishing',
#    'app': {'app_name': 'Call of Duty:Black Ops Zombies',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '39'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'Activision Publishing',
#    'app': {'app_name': 'Call of Duty:Black Ops Zombies',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '39'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'Activision Publishing',
#    'app': {'app_name': 'Call of Duty®: Mobile',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Free', 'rank': '165'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'Activision Publishing',
#    'app': {'app_name': 'Call of Duty®: Mobile',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Grossing', 'rank': '37'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'Activision Publishing',
#    'app': {'app_name': 'Call of Duty®: Mobile',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Free', 'rank': '205'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'Activision Publishing',
#    'app': {'app_name': 'Call of Duty®: Mobile',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Grossing', 'rank': '23'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'Adobe',
#    'app': {'app_name': 'Adobe Acrobat Reader: PDF Viewer, Editor & Creator',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Free', 'rank': '92'}}}}}]

# %%
current_pub_name = giant_query[0][1]
current_app_name = giant_query[0][2]
date_array = []
app_array = []
publisher_name_dict = {}
app_name_dict = {}
date_dict = {}
all_apps = []
for platform, publisher_name, app_name, date, category, rank  in giant_query:
    
    if app_name != current_app_name:
        app_name_dict["app_name"] = current_app_name
        app_name_dict["date"] = date_array
        date_array = []
        current_app_name = app_name
        app_array.append(app_name_dict)
        app_name_dict = {}
        
    if publisher_name != current_pub_name:
        publisher_name_dict["platform"] = platform
        publisher_name_dict["publisher_name"] = current_pub_name
        publisher_name_dict["app"] = app_array
        app_array = []
        current_pub_name = publisher_name
        all_apps.append(publisher_name_dict)
        publisher_name_dict = {}
        
        
    date_dict["date"] = date
    date_dict["category"] = category
    date_dict["rank"] = rank
    date_array.append(date_dict)
    date_dict = {}

# %%
all_apps
# Out:
# [{'platform': 'Android',
#   'publisher_name': '⭐ Live Wallpapers HD ⭐',
#   'app': [{'app_name': 'Glitter Live Wallpaper',
#     'date': [{'date': '2021-01-26', 'category': 'Free', 'rank': '192'}]}]},
#  {'platform': 'Android',
#   'publisher_name': '1Debit',
#   'app': [{'app_name': 'Chime - Mobile Banking',
#     'date': [{'date': '2021-01-26', 'category': 'Free', 'rank': '140'},
#      {'date': '2021-01-27', 'category': 'Free', 'rank': '133'}]}]},
#  {'platform': 'Android',
#   'publisher_name': '2K Games',
#   'app': [{'app_name': 'Civilization Revolution 2',
#     'date': [{'date': '2021-01-26', 'category': 'Paid', 'rank': '194'},
#      {'date': '2021-01-27', 'category': 'Paid', 'rank': '198'}]},
#    {'app_name': 'NBA 2K20',
#     'date': [{'date': '2021-01-26', 'category': 'Paid', 'rank': '54'},
#      {'date': '2021-01-27', 'category': 'Paid', 'rank': '65'}]},
#    {'app_name': 'WWE SuperCard - Multiplayer Collector Card Game',
#     'date': [{'date': '2021-01-26', 'category': 'Grossing', 'rank': '144'},
#      {'date': '2021-01-27', 'category': 'Grossing', 'rank': '141'}]},
#    {'app_name': 'XCOM®: Enemy Within',
#     'date': [{'date': '2021-01-26', 'category': 'Paid', 'rank': '227'},
#      {'date': '2021-01-27', 'category': 'Paid', 'rank': '248'}]}]},
#  {'platform': 'Android',
#   'publisher_name': '2kit Consulting',
#   'app': [{'app_name': 'Screen Mirroring Pro App',
#     'date': [{'date': '2021-01-26', 'category': 'Paid', 'rank': '93'},
#      {'date': '2021-01-27', 'category': 'Paid', 'rank': '88'}]},
#    {'app_name': 'Screen Mirroring Pro for Fire TV',
#     'date': [{'date': '2021-01-26', 'category': 'Paid', 'rank': '112'},
#      {'date': '2021-01-27', 'category': 'Paid', 'rank': '112'}]},
#    {'app_name': 'Screen Mirroring Pro for Roku',
#     'date': [{'date': '2021-01-26', 'category': 'Paid', 'rank': '80'},
#      {'date': '2021-01-27', 'category': 'Paid', 'rank': '77'}]},
#    {'app_name': 'Video & TV Cast | Ultimate Edition',
#     'date': [{'date': '2021-01-26', 'category': 'Paid', 'rank': '109'},
#      {'date': '2021-01-27', 'category': 'Paid', 'rank': '113'}]},
#    {'app_name': 'Video & TV Cast + Fire TV | Web Video Browser',
#     'date': [{'date': '2021-01-26', 'category': 'Paid', 'rank': '132'},
#      {'date': '2021-01-27', 'category': 'Paid', 'rank': '139'}]},
#    {'app_name': 'Video & TV Cast + Google Cast: Android TV Streamer',
#     'date': [{'date': '2021-01-26', 'category': 'Paid', 'rank': '192'},
#      {'date': '2021-01-27', 'category': 'Paid', 'rank': '192'}]},
#    {'app_name': 'Video & TV Cast + Roku Remote & Movie Stream App',
#     'date': [{'date': '2021-01-26', 'category': 'Paid', 'rank': '143'},
#      {'date': '2021-01-27', 'category': 'Paid', 'rank': '147'}]}]},
#  {'platform': 'Android',
#   'publisher_name': '37games',
#   'app': [{'app_name': 'Puzzles & Conquest',
#     'date': [{'date': '2021-01-26', 'category': 'Grossing', 'rank': '192'},
#      {'date': '2021-01-27', 'category': 'Grossing', 'rank': '193'}]},
#    {'app_name': 'Puzzles & Survival',
#     'date': [{'date': '2021-01-26', 'category': 'Free', 'rank': '162'},
#      {'date': '2021-01-26', 'category': 'Grossing', 'rank': '67'},
#      {'date': '2021-01-27', 'category': 'Free', 'rank': '161'},
#      {'date': '2021-01-27', 'category': 'Grossing', 'rank': '67'}]}]},
#  {'platform': 'Android',
#   'publisher_name': '44SEVEN MEDIA',
#   'app': [{'app_name': '75 Hard',
#     'date': [{'date': '2021-01-26', 'category': 'Paid', 'rank': '64'},
#      {'date': '2021-01-27', 'category': 'Paid', 'rank': '59'}]}]},
#  {'platform': 'Android',
#   'publisher_name': '505 Games',
#   'app': [{'app_name': 'Human: Fall Flat',
#     'date': [{'date': '2021-01-26', 'category': 'Paid', 'rank': '24'},
#      {'date': '2021-01-27', 'category': 'Paid', 'rank': '20'}]},
#    {'app_name': 'Terraria',
#     'date': [{'date': '2021-01-26', 'category': 'Paid', 'rank': '8'},
#      {'date': '2021-01-27', 'category': 'Paid', 'rank': '8'}]}]},
#  {'platform': 'Android',
#   'publisher_name': '89Trillion',
#   'app': [{'app_name': 'Art of War: Legions',
#     'date': [{'date': '2021-01-26', 'category': 'Grossing', 'rank': '165'},
#      {'date': '2021-01-27', 'category': 'Grossing', 'rank': '168'}]}]},
#  {'platform': 'Android',
#   'publisher_name': 'ACME AtronOmatic',
#   'app': [{'app_name': 'MyRadar Weather Radar Ad Free',
#     'date': [{'date': '2021-01-26', 'category': 'Paid', 'rank': '215'},
#      {'date': '2021-01-27', 'category': 'Paid', 'rank': '211'}]}]},
#  {'platform': 'Android',
#   'publisher_name': 'ActiveNetwork',
#   'app': [{'app_name': 'Couch to 5K®',
#     'date': [{'date': '2021-01-26', 'category': 'Paid', 'rank': '231'},
#      {'date': '2021-01-27', 'category': 'Paid', 'rank': '269'}]}]},
#  {'platform': 'Android',
#   'publisher_name': 'Activision Publishing',
#   'app': [{'app_name': 'Call of Duty:Black Ops Zombies',
#     'date': [{'date': '2021-01-26', 'category': 'Paid', 'rank': '39'},
#      {'date': '2021-01-27', 'category': 'Paid', 'rank': '39'}]},
#    {'app_name': 'Call of Duty®: Mobile',
#     'date': [{'date': '2021-01-26', 'category': 'Free', 'rank': '165'},
#      {'date': '2021-01-26', 'category': 'Grossing', 'rank': '37'},
#      {'date': '2021-01-27', 'category': 'Free', 'rank': '205'},
#      {'date': '2021-01-27', 'category': 'Grossing', 'rank': '23'}]}]}]
