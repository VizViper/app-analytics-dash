# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import func
from flask import Flask, jsonify

# %%
# Create an engine for the database
engine = create_engine("postgresql://test:12345@localhost:5432/app_rankings")

# %%
# Reflect Database into ORM classes
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['category', 'application', 'publisher', 'ranking', 'platform']

# %% [markdown]
# Save references to the tables

# %%
category = Base.classes.category
application = Base.classes.application
publisher = Base.classes.publisher
ranking = Base.classes.ranking
platform = Base.classes.platform

# %%
# Create a database session object
session = Session(engine)

# %%
sel = [platform.platform, publisher.publisher_name, application.app_name, ranking.date, category.category, ranking.rank]

# %%
giant_query = session.query(*sel).filter(ranking.app_id == application.app_id).filter(ranking.category_id == category.category_id).filter(ranking.platform_id == platform.platform_id).filter(application.publisher_id == publisher.publisher_id).filter(category.category_id == 2).order_by(platform.platform).order_by(publisher.publisher_name).order_by(application.app_name).order_by(ranking.date).order_by(category.category).order_by(ranking.rank).limit(50).all()

# %%
giant_query
# Out:
# [('Android',
#   '2K Games',
#   'WWE SuperCard - Multiplayer Collector Card Game',
#   '2021-01-26',
#   'Grossing',
#   '144'),
#  ('Android',
#   '2K Games',
#   'WWE SuperCard - Multiplayer Collector Card Game',
#   '2021-01-27',
#   'Grossing',
#   '141'),
#  ('Android', '37games', 'Puzzles & Conquest', '2021-01-26', 'Grossing', '192'),
#  ('Android', '37games', 'Puzzles & Conquest', '2021-01-27', 'Grossing', '193'),
#  ('Android', '37games', 'Puzzles & Survival', '2021-01-26', 'Grossing', '67'),
#  ('Android', '37games', 'Puzzles & Survival', '2021-01-27', 'Grossing', '67'),
#  ('Android',
#   '89Trillion',
#   'Art of War: Legions',
#   '2021-01-26',
#   'Grossing',
#   '165'),
#  ('Android',
#   '89Trillion',
#   'Art of War: Legions',
#   '2021-01-27',
#   'Grossing',
#   '168'),
#  ('Android',
#   'Activision Publishing',
#   'Call of Duty®: Mobile',
#   '2021-01-26',
#   'Grossing',
#   '37'),
#  ('Android',
#   'Activision Publishing',
#   'Call of Duty®: Mobile',
#   '2021-01-27',
#   'Grossing',
#   '23'),
#  ('Android',
#   'Adobe',
#   'Adobe Acrobat Reader: PDF Viewer, Editor & Creator',
#   '2021-01-26',
#   'Grossing',
#   '227'),
#  ('Android',
#   'Adobe',
#   'Adobe Acrobat Reader: PDF Viewer, Editor & Creator',
#   '2021-01-27',
#   'Grossing',
#   '225'),
#  ('Android',
#   'Aniplex',
#   'Fate/Grand Order (English)',
#   '2021-01-26',
#   'Grossing',
#   '44'),
#  ('Android',
#   'Aniplex',
#   'Fate/Grand Order (English)',
#   '2021-01-27',
#   'Grossing',
#   '44'),
#  ('Android', 'Auxbrain', 'Egg, Inc.', '2021-01-26', 'Grossing', '224'),
#  ('Android', 'Auxbrain', 'Egg, Inc.', '2021-01-27', 'Grossing', '221'),
#  ('Android',
#   'Avid.ly',
#   'Bingo Party - Free Classic Bingo Games Online',
#   '2021-01-26',
#   'Grossing',
#   '217'),
#  ('Android',
#   'Avid.ly',
#   'Bingo Party - Free Classic Bingo Games Online',
#   '2021-01-27',
#   'Grossing',
#   '203'),
#  ('Android',
#   'BANDAI NAMCO Entertainment',
#   'DRAGON BALL LEGENDS',
#   '2021-01-26',
#   'Grossing',
#   '48'),
#  ('Android',
#   'BANDAI NAMCO Entertainment',
#   'DRAGON BALL LEGENDS',
#   '2021-01-27',
#   'Grossing',
#   '47'),
#  ('Android',
#   'BANDAI NAMCO Entertainment',
#   'DRAGON BALL Z DOKKAN BATTLE',
#   '2021-01-26',
#   'Grossing',
#   '57'),
#  ('Android',
#   'BANDAI NAMCO Entertainment',
#   'DRAGON BALL Z DOKKAN BATTLE',
#   '2021-01-27',
#   'Grossing',
#   '57'),
#  ('Android', 'BET Networks', 'BET+', '2021-01-26', 'Grossing', '254'),
#  ('Android', 'BET Networks', 'BET+', '2021-01-27', 'Grossing', '253'),
#  ('Android',
#   'BIGO',
#   'BIGO LIVE–Live Stream, Live Chat, Go Live',
#   '2021-01-26',
#   'Grossing',
#   '58'),
#  ('Android',
#   'BIGO',
#   'BIGO LIVE–Live Stream, Live Chat, Go Live',
#   '2021-01-27',
#   'Grossing',
#   '58'),
#  ('Android', 'BIGO', 'Likee - Let You Shine', '2021-01-26', 'Grossing', '288'),
#  ('Android', 'BIGO', 'Likee - Let You Shine', '2021-01-27', 'Grossing', '286'),
#  ('Android',
#   'Babbel',
#   'Babbel - Learn Languages - Spanish, French & More',
#   '2021-01-26',
#   'Grossing',
#   '300'),
#  ('Android',
#   'Babbel',
#   'Babbel - Learn Languages - Spanish, French & More',
#   '2021-01-27',
#   'Grossing',
#   '298'),
#  ('Android',
#   'Bagelcode',
#   'Club Vegas 2021: New Slots Games & Casino bonuses',
#   '2021-01-26',
#   'Grossing',
#   '163'),
#  ('Android',
#   'Bagelcode',
#   'Club Vegas 2021: New Slots Games & Casino bonuses',
#   '2021-01-27',
#   'Grossing',
#   '166'),
#  ('Android',
#   'Beach Bum',
#   'Spades Royale -Best Social Card Game',
#   '2021-01-26',
#   'Grossing',
#   '206'),
#  ('Android',
#   'Beach Bum',
#   'Spades Royale -Best Social Card Game',
#   '2021-01-27',
#   'Grossing',
#   '205'),
#  ('Android',
#   'Big Fish Games',
#   'Big Fish Casino - Play Slots and Casino Games',
#   '2021-01-26',
#   'Grossing',
#   '88'),
#  ('Android',
#   'Big Fish Games',
#   'Big Fish Casino - Play Slots and Casino Games',
#   '2021-01-27',
#   'Grossing',
#   '88'),
#  ('Android', 'Big Fish Games', 'EverMerge', '2021-01-26', 'Grossing', '91'),
#  ('Android', 'Big Fish Games', 'EverMerge', '2021-01-27', 'Grossing', '91'),
#  ('Android',
#   'Big Fish Games',
#   'Gummy Drop! Match to restore and build cities',
#   '2021-01-26',
#   'Grossing',
#   '275'),
#  ('Android',
#   'Big Fish Games',
#   'Gummy Drop! Match to restore and build cities',
#   '2021-01-27',
#   'Grossing',
#   '274'),
#  ('Android',
#   'Big Fish Games',
#   'Jackpot Magic Slots™: Social Casino & Slot Games',
#   '2021-01-26',
#   'Grossing',
#   '130'),
#  ('Android',
#   'Big Fish Games',
#   'Jackpot Magic Slots™: Social Casino & Slot Games',
#   '2021-01-27',
#   'Grossing',
#   '148'),
#  ('Android',
#   'Blizzard Entertainment',
#   'Hearthstone',
#   '2021-01-26',
#   'Grossing',
#   '283'),
#  ('Android',
#   'Blizzard Entertainment',
#   'Hearthstone',
#   '2021-01-27',
#   'Grossing',
#   '282'),
#  ('Android',
#   'Bole Games',
#   'Cash Frenzy™ Casino – Free Slots Games',
#   '2021-01-26',
#   'Grossing',
#   '30'),
#  ('Android',
#   'Bole Games',
#   'Cash Frenzy™ Casino – Free Slots Games',
#   '2021-01-27',
#   'Grossing',
#   '31'),
#  ('Android',
#   'Bole Games',
#   'Jackpot Crush – Free Vegas Slot Machines',
#   '2021-01-26',
#   'Grossing',
#   '252'),
#  ('Android',
#   'Bole Games',
#   'Jackpot Crush – Free Vegas Slot Machines',
#   '2021-01-27',
#   'Grossing',
#   '250'),
#  ('Android',
#   'Bole Games',
#   'Jackpot World™ - Free Vegas Casino Slots',
#   '2021-01-26',
#   'Grossing',
#   '107'),
#  ('Android',
#   'Bole Games',
#   'Jackpot World™ - Free Vegas Casino Slots',
#   '2021-01-27',
#   'Grossing',
#   '108')]

# %%
all_apps = []

# %%
platform_previous = 0
publisher_name_previous = 0
app_name_previous = 0
date_previous = 0
category_previous = 0
rank_previous = 0

# %%
# for platform, publisher_name, app_name, date, category, rank  in giant_query:
#     if platform_previous = platform:

#         if publisher_name_previous = publisher:
            
#             if app_name_previous = app_name:
                
#                 if date_previous = date:
#                     category_dict["category"] = category
#                     category_dict["rank"] = rank
#                 else:
#                     date_dict["date"] = date
#                     date_dict["category"] = category_dict
                    
#                     category_dict["category"] = category
#                     category_dict["rank"] = rank
#             else:
#                 app_name_dict["app_name"] = app_name
#                 app_name_dict["date"] = date_dict
                
#                 date_dict["date"] = date
#                 date_dict["category"] = category_dict
    
#                 category_dict["category"] = category
#                 category_dict["rank"] = rank
#     else:
#         all_apps.append(app_rankings_dict)
    
#         app_rankings_dict = {}
#         publisher_name_dict = {}
#         app_name_dict = {}
#         date_dict = {}
#         category_dict = {}
    
#         platform_previous = 0
#         publisher_name_previous = 0
#         app_name_previous = 0
#         date_previous = 0
#         category_previous = 0
#         rank_previous = 0

#         app_rankings_dict["platform"] = platform
#         app_rankings_dict["publisher"] = publisher_name_dict 
    
#         publisher_name_dict["publisher_name"] = publisher_name
#         publisher_name_dict["app"] = app_name_dict
    
#         app_name_dict["app_name"] = app_name
#         app_name_dict["date"] = date_dict
    
#         date_dict["date"] = date
#         date_dict["category"] = category_dict
    
#         category_dict["category"] = category
#         category_dict["rank"] = rank
    
    
#         all_apps.append(app_rankings_dict)

# %%
# for platform, publisher_name, app_name, date, category, rank  in giant_query:
#     app_rankings_dict = {}
#     publisher_name_dict = {}
#     app_name_dict = {}
#     date_dict = {}
#     category_dict = {}

#     app_rankings_dict["platform"] = platform
#     app_rankings_dict["publisher"] = publisher_name_dict 
    
#     publisher_name_dict["publisher_name"] = publisher_name
#     publisher_name_dict["app"] = app_name_dict
    
#     app_name_dict["app_name"] = app_name
#     app_name_dict["date"] = date_dict
    
#     date_dict["date"] = date
#     date_dict["category"] = category_dict
    
#     category_dict["category"] = category
#     category_dict["rank"] = rank
    
    
#     all_apps.append(app_rankings_dict)

# %%
all_apps
# Out:
# [{'platform': 'Android',
#   'publisher': {'publisher_name': '1Debit',
#    'app': {'app_name': 'Chime - Mobile Banking',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Free', 'rank': '140'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '1Debit',
#    'app': {'app_name': 'Chime - Mobile Banking',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Free', 'rank': '133'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {'app_name': 'Civilization Revolution 2',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '194'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {'app_name': 'Civilization Revolution 2',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '198'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {'app_name': 'NBA 2K20',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '54'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {'app_name': 'NBA 2K20',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '65'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {'app_name': 'WWE SuperCard - Multiplayer Collector Card Game',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Grossing', 'rank': '144'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {'app_name': 'WWE SuperCard - Multiplayer Collector Card Game',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Grossing', 'rank': '141'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {'app_name': 'XCOM®: Enemy Within',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '227'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {'app_name': 'XCOM®: Enemy Within',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '248'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Screen Mirroring Pro App',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '93'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Screen Mirroring Pro App',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '88'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Screen Mirroring Pro for Fire TV',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '112'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Screen Mirroring Pro for Fire TV',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '112'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Screen Mirroring Pro for Roku',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '80'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Screen Mirroring Pro for Roku',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '77'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Video & TV Cast + Fire TV | Web Video Browser',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '132'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Video & TV Cast + Fire TV | Web Video Browser',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '139'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Video & TV Cast + Google Cast: Android TV Streamer',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '192'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Video & TV Cast + Google Cast: Android TV Streamer',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '192'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Video & TV Cast + Roku Remote & Movie Stream App',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '143'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Video & TV Cast + Roku Remote & Movie Stream App',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '147'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Video & TV Cast | Ultimate Edition',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '109'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2kit Consulting',
#    'app': {'app_name': 'Video & TV Cast | Ultimate Edition',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '113'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '37games',
#    'app': {'app_name': 'Puzzles & Conquest',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Grossing', 'rank': '192'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '37games',
#    'app': {'app_name': 'Puzzles & Conquest',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Grossing', 'rank': '193'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '37games',
#    'app': {'app_name': 'Puzzles & Survival',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Free', 'rank': '162'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '37games',
#    'app': {'app_name': 'Puzzles & Survival',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Grossing', 'rank': '67'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '37games',
#    'app': {'app_name': 'Puzzles & Survival',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Free', 'rank': '161'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '37games',
#    'app': {'app_name': 'Puzzles & Survival',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Grossing', 'rank': '67'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '44SEVEN MEDIA',
#    'app': {'app_name': '75 Hard',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '64'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '44SEVEN MEDIA',
#    'app': {'app_name': '75 Hard',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '59'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '505 Games',
#    'app': {'app_name': 'Human: Fall Flat',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '24'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '505 Games',
#    'app': {'app_name': 'Human: Fall Flat',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '20'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '505 Games',
#    'app': {'app_name': 'Terraria',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '8'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '505 Games',
#    'app': {'app_name': 'Terraria',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '8'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '89Trillion',
#    'app': {'app_name': 'Art of War: Legions',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Grossing', 'rank': '165'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '89Trillion',
#    'app': {'app_name': 'Art of War: Legions',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Grossing', 'rank': '168'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'ACME AtronOmatic',
#    'app': {'app_name': 'MyRadar Weather Radar Ad Free',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '215'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'ACME AtronOmatic',
#    'app': {'app_name': 'MyRadar Weather Radar Ad Free',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '211'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'ADP, INC.',
#    'app': {'app_name': 'ADP Mobile Solutions',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Free', 'rank': '283'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'ADP, INC.',
#    'app': {'app_name': 'ADP Mobile Solutions',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Free', 'rank': '277'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'ADVA Soft',
#    'app': {'app_name': 'TouchRetouch',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '84'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'ADVA Soft',
#    'app': {'app_name': 'TouchRetouch',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '79'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'AFELL APPS',
#    'app': {'app_name': 'Nano Teleprompter',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '214'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'AFELL APPS',
#    'app': {'app_name': 'Nano Teleprompter',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '208'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'AGaming',
#    'app': {'app_name': 'The Sun Origin: Post-apocalyptic action shooter',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '255'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'AGaming',
#    'app': {'app_name': 'The Sun Origin: Post-apocalyptic action shooter',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '266'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'AI Factory',
#    'app': {'app_name': 'Chess',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '57'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': 'AI Factory',
#    'app': {'app_name': 'Chess',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '57'}}}}}]

# %%
current_pub_name = giant_query[0][1]
current_app_name = giant_query[0][2]
date_array = []
app_array = []
publisher_name_dict = {}
app_name_dict = {}
date_dict = {}
all_apps = []
for platform, publisher_name, app_name, date, category, rank  in giant_query:
    
    if app_name != current_app_name:
        app_name_dict["app_name"] = current_app_name
        app_name_dict["date"] = date_array
        date_array = []
        current_app_name = app_name
        app_array.append(app_name_dict)
        app_name_dict = {}
        
    if publisher_name != current_pub_name:
        publisher_name_dict["platform"] = platform
        publisher_name_dict["publisher_name"] = current_pub_name
        publisher_name_dict["app"] = app_array
        app_array = []
        current_pub_name = publisher_name
        all_apps.append(publisher_name_dict)
        publisher_name_dict = {}
        
        
    date_dict["date"] = date
    date_dict[f'{category}'] = rank
#     date_dict["rank"] = rank
    date_array.append(date_dict)
    date_dict = {}

# %%
all_apps
# Out:
# [{'platform': 'Android',
#   'publisher_name': '2K Games',
#   'app': [{'app_name': 'WWE SuperCard - Multiplayer Collector Card Game',
#     'date': [{'date': '2021-01-26', 'Grossing': '144'},
#      {'date': '2021-01-27', 'Grossing': '141'}]}]},
#  {'platform': 'Android',
#   'publisher_name': '37games',
#   'app': [{'app_name': 'Puzzles & Conquest',
#     'date': [{'date': '2021-01-26', 'Grossing': '192'},
#      {'date': '2021-01-27', 'Grossing': '193'}]},
#    {'app_name': 'Puzzles & Survival',
#     'date': [{'date': '2021-01-26', 'Grossing': '67'},
#      {'date': '2021-01-27', 'Grossing': '67'}]}]},
#  {'platform': 'Android',
#   'publisher_name': '89Trillion',
#   'app': [{'app_name': 'Art of War: Legions',
#     'date': [{'date': '2021-01-26', 'Grossing': '165'},
#      {'date': '2021-01-27', 'Grossing': '168'}]}]},
#  {'platform': 'Android',
#   'publisher_name': 'Activision Publishing',
#   'app': [{'app_name': 'Call of Duty®: Mobile',
#     'date': [{'date': '2021-01-26', 'Grossing': '37'},
#      {'date': '2021-01-27', 'Grossing': '23'}]}]},
#  {'platform': 'Android',
#   'publisher_name': 'Adobe',
#   'app': [{'app_name': 'Adobe Acrobat Reader: PDF Viewer, Editor & Creator',
#     'date': [{'date': '2021-01-26', 'Grossing': '227'},
#      {'date': '2021-01-27', 'Grossing': '225'}]}]},
#  {'platform': 'Android',
#   'publisher_name': 'Aniplex',
#   'app': [{'app_name': 'Fate/Grand Order (English)',
#     'date': [{'date': '2021-01-26', 'Grossing': '44'},
#      {'date': '2021-01-27', 'Grossing': '44'}]}]},
#  {'platform': 'Android',
#   'publisher_name': 'Auxbrain',
#   'app': [{'app_name': 'Egg, Inc.',
#     'date': [{'date': '2021-01-26', 'Grossing': '224'},
#      {'date': '2021-01-27', 'Grossing': '221'}]}]},
#  {'platform': 'Android',
#   'publisher_name': 'Avid.ly',
#   'app': [{'app_name': 'Bingo Party - Free Classic Bingo Games Online',
#     'date': [{'date': '2021-01-26', 'Grossing': '217'},
#      {'date': '2021-01-27', 'Grossing': '203'}]}]},
#  {'platform': 'Android',
#   'publisher_name': 'BANDAI NAMCO Entertainment',
#   'app': [{'app_name': 'DRAGON BALL LEGENDS',
#     'date': [{'date': '2021-01-26', 'Grossing': '48'},
#      {'date': '2021-01-27', 'Grossing': '47'}]},
#    {'app_name': 'DRAGON BALL Z DOKKAN BATTLE',
#     'date': [{'date': '2021-01-26', 'Grossing': '57'},
#      {'date': '2021-01-27', 'Grossing': '57'}]}]},
#  {'platform': 'Android',
#   'publisher_name': 'BET Networks',
#   'app': [{'app_name': 'BET+',
#     'date': [{'date': '2021-01-26', 'Grossing': '254'},
#      {'date': '2021-01-27', 'Grossing': '253'}]}]},
#  {'platform': 'Android',
#   'publisher_name': 'BIGO',
#   'app': [{'app_name': 'BIGO LIVE–Live Stream, Live Chat, Go Live',
#     'date': [{'date': '2021-01-26', 'Grossing': '58'},
#      {'date': '2021-01-27', 'Grossing': '58'}]},
#    {'app_name': 'Likee - Let You Shine',
#     'date': [{'date': '2021-01-26', 'Grossing': '288'},
#      {'date': '2021-01-27', 'Grossing': '286'}]}]},
#  {'platform': 'Android',
#   'publisher_name': 'Babbel',
#   'app': [{'app_name': 'Babbel - Learn Languages - Spanish, French & More',
#     'date': [{'date': '2021-01-26', 'Grossing': '300'},
#      {'date': '2021-01-27', 'Grossing': '298'}]}]},
#  {'platform': 'Android',
#   'publisher_name': 'Bagelcode',
#   'app': [{'app_name': 'Club Vegas 2021: New Slots Games & Casino bonuses',
#     'date': [{'date': '2021-01-26', 'Grossing': '163'},
#      {'date': '2021-01-27', 'Grossing': '166'}]}]},
#  {'platform': 'Android',
#   'publisher_name': 'Beach Bum',
#   'app': [{'app_name': 'Spades Royale -Best Social Card Game',
#     'date': [{'date': '2021-01-26', 'Grossing': '206'},
#      {'date': '2021-01-27', 'Grossing': '205'}]}]},
#  {'platform': 'Android',
#   'publisher_name': 'Big Fish Games',
#   'app': [{'app_name': 'Big Fish Casino - Play Slots and Casino Games',
#     'date': [{'date': '2021-01-26', 'Grossing': '88'},
#      {'date': '2021-01-27', 'Grossing': '88'}]},
#    {'app_name': 'EverMerge',
#     'date': [{'date': '2021-01-26', 'Grossing': '91'},
#      {'date': '2021-01-27', 'Grossing': '91'}]},
#    {'app_name': 'Gummy Drop! Match to restore and build cities',
#     'date': [{'date': '2021-01-26', 'Grossing': '275'},
#      {'date': '2021-01-27', 'Grossing': '274'}]},
#    {'app_name': 'Jackpot Magic Slots™: Social Casino & Slot Games',
#     'date': [{'date': '2021-01-26', 'Grossing': '130'},
#      {'date': '2021-01-27', 'Grossing': '148'}]}]},
#  {'platform': 'Android',
#   'publisher_name': 'Blizzard Entertainment',
#   'app': [{'app_name': 'Hearthstone',
#     'date': [{'date': '2021-01-26', 'Grossing': '283'},
#      {'date': '2021-01-27', 'Grossing': '282'}]}]}]
