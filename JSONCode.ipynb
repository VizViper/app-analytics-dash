# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import func
from flask import Flask, jsonify

# %%
# Create an engine for the database
engine = create_engine("postgresql://postgres:postgres@localhost:5432/app_rankings")

# %%
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1276                 if not evt_handled:
# -> 1277                     self.dialect.do_execute(
#    1278                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# UndefinedColumn: column "index" named in key does not exist
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-5-d5f8cc164d79> in <module>
# ...

# %%
# Reflect Database into ORM classes
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['category', 'application', 'publisher', 'platform', 'ranking']

# %% [markdown]
# Save references to the tables

# %%
category = Base.classes.category
application = Base.classes.application
publisher = Base.classes.publisher
ranking = Base.classes.ranking
platform = Base.classes.platform

# %%
# Create a database session object
session = Session(engine)

# %%
sel = [platform.platform, publisher.publisher_name, application.app_name, ranking.date, category.category, ranking.rank]

# %%
giant_query = session.query(*sel).filter(ranking.app_id == application.app_id).filter(ranking.category_id == category.category_id).filter(ranking.platform_id == platform.platform_id).filter(application.publisher_id == publisher.publisher_id).filter(category.category_id == 2).order_by(platform.platform).order_by(publisher.publisher_name).order_by(application.app_name).order_by(ranking.date).order_by(category.category).order_by(ranking.rank).limit(50).all()

# %%
giant_query
# Out:
# [('Android',
#   '111%',
#   'Random Dice: PvP Defense',
#   '2020-12-01',
#   'Grossing',
#   '262'),
#  ('Android',
#   '111%',
#   'Random Dice: PvP Defense',
#   '2020-12-02',
#   'Grossing',
#   '278'),
#  ('Android',
#   '111%',
#   'Random Dice: PvP Defense',
#   '2020-12-03',
#   'Grossing',
#   '286'),
#  ('Android',
#   '111%',
#   'Random Dice: PvP Defense',
#   '2020-12-04',
#   'Grossing',
#   '292'),
#  ('Android',
#   '111%',
#   'Random Dice: PvP Defense',
#   '2020-12-05',
#   'Grossing',
#   '285'),
#  ('Android',
#   '111%',
#   'Random Dice: PvP Defense',
#   '2020-12-06',
#   'Grossing',
#   '282'),
#  ('Android',
#   '111%',
#   'Random Dice: PvP Defense',
#   '2020-12-07',
#   'Grossing',
#   '284'),
#  ('Android',
#   '2K Games',
#   'WWE SuperCard – Multiplayer Card Battle Game',
#   '2020-12-01',
#   'Grossing',
#   '130'),
#  ('Android',
#   '2K Games',
#   'WWE SuperCard – Multiplayer Card Battle Game',
#   '2020-12-02',
#   'Grossing',
#   '125'),
# ...

# %%
all_apps = []

# %%
platform_previous = 0
publisher_name_previous = 0
app_name_previous = 0
date_previous = 0
category_previous = 0
rank_previous = 0

# %%
# for platform, publisher_name, app_name, date, category, rank  in giant_query:
#     if platform_previous = platform:

#         if publisher_name_previous = publisher:
            
#             if app_name_previous = app_name:
                
#                 if date_previous = date:
#                     category_dict["category"] = category
#                     category_dict["rank"] = rank
#                 else:
#                     date_dict["date"] = date
#                     date_dict["category"] = category_dict
                    
#                     category_dict["category"] = category
#                     category_dict["rank"] = rank
#             else:
#                 app_name_dict["app_name"] = app_name
#                 app_name_dict["date"] = date_dict
                
#                 date_dict["date"] = date
#                 date_dict["category"] = category_dict
    
#                 category_dict["category"] = category
#                 category_dict["rank"] = rank
#     else:
#         all_apps.append(app_rankings_dict)
    
#         app_rankings_dict = {}
#         publisher_name_dict = {}
#         app_name_dict = {}
#         date_dict = {}
#         category_dict = {}
    
#         platform_previous = 0
#         publisher_name_previous = 0
#         app_name_previous = 0
#         date_previous = 0
#         category_previous = 0
#         rank_previous = 0

#         app_rankings_dict["platform"] = platform
#         app_rankings_dict["publisher"] = publisher_name_dict 
    
#         publisher_name_dict["publisher_name"] = publisher_name
#         publisher_name_dict["app"] = app_name_dict
    
#         app_name_dict["app_name"] = app_name
#         app_name_dict["date"] = date_dict
    
#         date_dict["date"] = date
#         date_dict["category"] = category_dict
    
#         category_dict["category"] = category
#         category_dict["rank"] = rank
    
    
#         all_apps.append(app_rankings_dict)

# %%
# for platform, publisher_name, app_name, date, category, rank  in giant_query:
#     app_rankings_dict = {}
#     publisher_name_dict = {}
#     app_name_dict = {}
#     date_dict = {}
#     category_dict = {}

#     app_rankings_dict["platform"] = platform
#     app_rankings_dict["publisher"] = publisher_name_dict 
    
#     publisher_name_dict["publisher_name"] = publisher_name
#     publisher_name_dict["app"] = app_name_dict
    
#     app_name_dict["app_name"] = app_name
#     app_name_dict["date"] = date_dict
    
#     date_dict["date"] = date
#     date_dict["category"] = category_dict
    
#     category_dict["category"] = category
#     category_dict["rank"] = rank
    
    
#     all_apps.append(app_rankings_dict)

# %%
all_apps
# Out:
# [{'platform': 'Android',
#   'publisher': {'publisher_name': '1Debit',
#    'app': {'app_name': 'Chime - Mobile Banking',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Free', 'rank': '140'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '1Debit',
#    'app': {'app_name': 'Chime - Mobile Banking',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Free', 'rank': '133'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {'app_name': 'Civilization Revolution 2',
#     'date': {'date': '2021-01-26',
#      'category': {'category': 'Paid', 'rank': '194'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
#    'app': {'app_name': 'Civilization Revolution 2',
#     'date': {'date': '2021-01-27',
#      'category': {'category': 'Paid', 'rank': '198'}}}}},
#  {'platform': 'Android',
#   'publisher': {'publisher_name': '2K Games',
# ...

# %%
current_pub_name = giant_query[0][1]
current_app_name = giant_query[0][2]
date_array = []
app_array = []
publisher_name_dict = {}
app_name_dict = {}
date_dict = {}
all_apps = []
for platform, publisher_name, app_name, date, category, rank  in giant_query:
    
    if app_name != current_app_name:
        app_name_dict["app_name"] = current_app_name
        app_name_dict["date"] = date_array
        date_array = []
        current_app_name = app_name
        app_array.append(app_name_dict)
        app_name_dict = {}
        
    if publisher_name != current_pub_name:
        publisher_name_dict["platform"] = platform
        publisher_name_dict["publisher_name"] = current_pub_name
        publisher_name_dict["app"] = app_array
        app_array = []
        current_pub_name = publisher_name
        all_apps.append(publisher_name_dict)
        publisher_name_dict = {}
        
        
    date_dict["date"] = date
    date_dict[f'{category}'] = rank
#     date_dict["rank"] = rank
    date_array.append(date_dict)
    date_dict = {}

# %%
all_apps
# Out:
# [{'platform': 'Android',
#   'publisher_name': '111%',
#   'app': [{'app_name': 'Random Dice: PvP Defense',
#     'date': [{'date': '2020-12-01', 'Grossing': '262'},
#      {'date': '2020-12-02', 'Grossing': '278'},
#      {'date': '2020-12-03', 'Grossing': '286'},
#      {'date': '2020-12-04', 'Grossing': '292'},
#      {'date': '2020-12-05', 'Grossing': '285'},
#      {'date': '2020-12-06', 'Grossing': '282'},
#      {'date': '2020-12-07', 'Grossing': '284'}]}]},
#  {'platform': 'Android',
#   'publisher_name': '2K Games',
#   'app': [{'app_name': 'WWE SuperCard – Multiplayer Card Battle Game',
#     'date': [{'date': '2020-12-01', 'Grossing': '130'},
#      {'date': '2020-12-02', 'Grossing': '125'},
#      {'date': '2020-12-03', 'Grossing': '128'},
#      {'date': '2020-12-04', 'Grossing': '133'},
#      {'date': '2020-12-05', 'Grossing': '141'},
#      {'date': '2020-12-06', 'Grossing': '141'},
#      {'date': '2020-12-07', 'Grossing': '131'}]}]},
#  {'platform': 'Android',
# ...
