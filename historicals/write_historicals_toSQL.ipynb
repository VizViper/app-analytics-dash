# %%
# Pandas
import pandas as pd
import os
import chardet
# import dotenv
from datetime import datetime

# SQL Alchemy
import sqlalchemy as db
from sqlalchemy import create_engine
from sqlalchemy.orm import mapper
from sqlalchemy.orm import sessionmaker
from sqlalchemy.orm import relationship
from sqlalchemy.ext.declarative import declarative_base

# %%
# Create Engine for census data
# db_pass = os.getenv('db_pass')
historicals_csv = "Historical_App_Rankings_Combined.csv"
engine = create_engine(f'postgresql://test:12345@localhost:5432/app_rankings')
conn = engine.connect()

# %%
# Write table to SQL from CSV
with open(historicals_csv, 'rb') as f:
    result = chardet.detect(f.read())
    df = pd.read_csv(historicals_csv, encoding = result['encoding'])
    df.to_sql('ranking', con=engine, index=False, if_exists = 'append')
# Out:
# ---------------------------------------------------------------------------
# NotNullViolation                          Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                 if not evt_handled:
# -> 1257                     self.dialect.do_executemany(
#    1258                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# NotNullViolation: null value in column "index" of relation "ranking" violates not-null constraint
# DETAIL:  Failing row contains (null, 1/1/2020, 151, 620112416, 2, 1).
#
#
# ...
